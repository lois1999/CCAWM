# %% [markdown]
# # Results of experiments with transformer models on SCAN and NACS

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# Load all data into numpy array

# %%
def load_runs(results_path,n_runs):
    losses = []
    train_accs = []
    dev_accs = []
    test_accs = []
    for run in range(n_runs):
        fn = results_path + str(run) + '.json'
        with open(fn,'r') as f:
            results = json.load(f)
        losses.append(results['loss_data'])
        train_accs.append(results['train_accs'])
        dev_accs.append(results['dev_accs'])
        test_accs.append(results['test_accs'])
    losses = np.array(losses)
    train_accs = np.array(train_accs)
    dev_accs = np.array(dev_accs)
    test_accs = np.array(test_accs)
    return losses, train_accs, dev_accs, test_accs

# %%
n_runs = 5

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/simple_scan'
simple_scan_losses, simple_scan_train, simple_scan_dev, simple_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/simple_nacs'
simple_nacs_losses, simple_nacs_train, simple_nacs_dev, simple_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addleft_scan'
addleft_scan_losses, addleft_scan_train, addleft_scan_dev, addleft_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addleft_nacs'
addleft_nacs_losses, addleft_nacs_train, addleft_nacs_dev, addleft_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/length_scan'
length_scan_losses, length_scan_train, length_scan_dev, length_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/length_nacs'
length_nacs_losses, length_nacs_train, length_nacs_dev, length_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addjump_scan'
addjump_scan_losses, addjump_scan_train, addjump_scan_dev, addjump_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addjump_nacs'
addjump_nacs_losses, addjump_nacs_train, addjump_nacs_dev, addjump_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addleft_removedleft_scan'
addleft_removedleft_scan_losses, addleft_removedleft_scan_train, addleft_removedleft_scan_dev, addleft_removedleft_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addleft_removedleft_nacs'
addleft_removedleft_nacs_losses, addleft_removedleft_nacs_train, addleft_removedleft_nacs_dev, addleft_removedleft_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addx_scan'
addx_scan_losses, addx_scan_train, addx_scan_dev, addx_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addx_nacs'
addx_nacs_losses, addx_nacs_train, addx_nacs_dev, addx_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addjump_scan_secondrun'
addjump_scan_secondrun_losses, addjump_scan_secondrun_train, addjump_scan_secondrun_dev, addjump_scan_secondrun_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addjump_nacs_secondrun'
addjump_nacs_secondrun_losses, addjump_nacs_secondrun_train, addjump_nacs_secondrun_dev, addjump_nacs_secondrun_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addx_scan_secondrun'
addx_scan_secondrun_losses, addx_scan_secondrun_train, addx_scan_secondrun_dev, addx_scan_secondrun_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addx_nacs_secondrun'
addx_nacs_secondrun_losses, addx_nacs_secondrun_train, addx_nacs_secondrun_dev, addx_nacs_secondrun_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/split1_scan'
split1_scan_losses, split1_scan_train, split1_scan_dev, split1_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/split1_nacs'
split1_nacs_losses, split1_nacs_train, split1_nacs_dev, split1_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/split2_scan'
split2_scan_losses, split2_scan_train, split2_scan_dev, split2_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/split2_nacs'
split2_nacs_losses, split2_nacs_train, split2_nacs_dev, split2_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/jumpo_scan'
jumpo_scan_losses, jumpo_scan_train, jumpo_scan_dev, jumpo_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/jumpo_nacs'
jumpo_nacs_losses, jumpo_nacs_train, jumpo_nacs_dev, jumpo_nacs_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/uniquesuffix_scan'
uniquesuffix_scan_losses, uniquesuffix_scan_train, uniquesuffix_scan_dev, uniquesuffix_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/uniquesuffix_nacs'
uniquesuffix_nacs_losses, uniquesuffix_nacs_train, uniquesuffix_nacs_dev, uniquesuffix_nacs_test = load_runs(results_path,n_runs)

# %% [markdown]
# Plot losses

# %%
simple_scan_losses_ave = np.mean(simple_scan_losses,axis=0)
#print(simple_scan_losses)
simple_nacs_losses_ave = np.mean(simple_nacs_losses,axis=0)
# There is just one run in this case
plt.plot(simple_scan_losses_ave)
plt.plot(simple_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves Simple')
plt.legend(['Simple Scan','Simple Nacs'])
#plt.xlim([0,1000])
plt.ylim([0,3.5])
plt.show()

# %%
addleft_scan_losses_ave = np.mean(addleft_scan_losses,axis=0)
addleft_nacs_losses_ave = np.mean(addleft_nacs_losses,axis=0)
plt.plot(addleft_scan_losses_ave)
plt.plot(addleft_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves Left')
plt.legend(['Left Scan','Left Nacs']) 
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
length_scan_losses_ave = np.mean(length_scan_losses,axis=0)
length_nacs_losses_ave = np.mean(length_nacs_losses,axis=0)
plt.plot(length_scan_losses_ave)
plt.plot(length_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves Length')
plt.legend(['Length Scan','Length Nacs'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
addjump_scan_losses_ave = np.mean(addjump_scan_losses,axis=0)
addjump_nacs_losses_ave = np.mean(addjump_nacs_losses,axis=0)
plt.plot(addjump_scan_losses_ave)
plt.plot(addjump_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves Jump')
plt.legend(['Jump Scan','Jump Nacs'])
#plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
addleft_removedleft_scan_losses_ave = np.mean(addleft_removedleft_scan_losses,axis=0)
addleft_removedleft_nacs_losses_ave = np.mean(addleft_removedleft_nacs_losses,axis=0)
plt.plot(addleft_removedleft_scan_losses_ave)
plt.plot(addleft_removedleft_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves addleft_removedleft')
plt.legend(['addleft_removedleft_Scan','addleft_removedleft_Nacs'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
addx_scan_losses_ave = np.mean(addx_scan_losses,axis=0)
addx_nacs_losses_ave = np.mean(addx_nacs_losses,axis=0)
plt.plot(addx_scan_losses_ave)
plt.plot(addx_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves addx')
plt.legend(['addx_Scan','addx_Nacs'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
addjump_scan_secondrun_losses_ave = np.mean(addjump_scan_secondrun_losses,axis=0)
addjump_nacs_secondrun_losses_ave = np.mean(addjump_nacs_secondrun_losses,axis=0)
plt.plot(addjump_scan_secondrun_losses_ave)
plt.plot(addjump_nacs_secondrun_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves addjump_secondrun')
plt.legend(['addjump_scan_secondrun','addjump_nacs_secondrun'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
addx_scan_secondrun_losses_ave = np.mean(addx_scan_secondrun_losses,axis=0)
addx_nacs_secondrun_losses_ave = np.mean(addx_nacs_secondrun_losses,axis=0)
plt.plot(addx_scan_secondrun_losses_ave)
plt.plot(addx_nacs_secondrun_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves addx_secondrun')
plt.legend(['addx_scan_secondrun','addx_nacs_secondrun'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
split1_scan_losses_ave = np.mean(split1_scan_losses,axis=0)
split1_nacs_losses_ave = np.mean(split1_nacs_losses,axis=0)
plt.plot(split1_scan_losses_ave)
plt.plot(split1_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves split1')
plt.legend(['split1_scan', 'split1_nacs'])
#plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
split2_scan_losses_ave = np.mean(split2_scan_losses,axis=0)
split2_nacs_losses_ave = np.mean(split2_nacs_losses,axis=0)
plt.plot(split2_scan_losses_ave)
plt.plot(split2_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves split2')
plt.legend(['split2_scan', 'split2_nacs'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
jumpo_scan_losses_ave = np.mean(jumpo_scan_losses,axis=0)
jumpo_nacs_losses_ave = np.mean(jumpo_nacs_losses,axis=0)
plt.plot(jumpo_scan_losses_ave)
plt.plot(jumpo_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves jump-o')
plt.legend(['jumpo_scan', 'jumpo_nacs'])
#plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %%
uniquesuffix_scan_losses_ave = np.mean(uniquesuffix_scan_losses,axis=0)
uniquesuffix_nacs_losses_ave = np.mean(uniquesuffix_nacs_losses,axis=0)
plt.plot(uniquesuffix_scan_losses_ave)
plt.plot(uniquesuffix_nacs_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curves unique suffix')
plt.legend(['uniquesuffix_scan', 'uniquesuffix_nacs'])
plt.xlim([0,30])
plt.ylim([0,3.5])
plt.show()

# %% [markdown]
# Plot test accuracy

# %%
simple_scan_train_ave = np.mean([np.max([item[0] for item in simple_scan_train[i]]) for i in range(n_runs)])
simple_nacs_train_ave = np.mean([np.max(simple_nacs_train[i,:]) for i in range(n_runs)])
simple_scan_dev_ave = np.mean([np.max([item[0] for item in simple_scan_dev[i]]) for i in range(n_runs)])
simple_nacs_dev_ave = np.mean([np.max(simple_nacs_dev[i,:]) for i in range(n_runs)])
simple_scan_test_ave = np.mean([np.max([item[0] for item in simple_scan_test[i]]) for i in range(n_runs)])
simple_nacs_test_ave = np.mean([np.max(simple_nacs_test[i,:]) for i in range(n_runs)])

# %%
simple_scan_train_std = np.std([np.max([item[0] for item in simple_scan_train[i]]) for i in range(n_runs)])
simple_nacs_train_std = np.std([np.max(simple_nacs_train[i,:]) for i in range(n_runs)])
simple_scan_dev_std = np.std([np.max([item[0] for item in simple_scan_dev[i]]) for i in range(n_runs)])
simple_nacs_dev_std = np.std([np.max(simple_nacs_dev[i,:]) for i in range(n_runs)])
simple_scan_test_std = np.std([np.max([item[0] for item in simple_scan_test[i]]) for i in range(n_runs)])
simple_nacs_test_std = np.std([np.max(simple_nacs_test[i,:]) for i in range(n_runs)])
train_std = [simple_scan_train_std, simple_nacs_train_std]
dev_std = [simple_scan_dev_std, simple_nacs_dev_std]
test_std = [simple_scan_test_std, simple_nacs_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[simple_scan_train_ave,simple_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[simple_scan_dev_ave,simple_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[simple_scan_test_ave,simple_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['simple SCAN','simple NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "simple"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

print(simple_scan_test_ave, test_std[0])
print(simple_nacs_test_ave, test_std[1])
# Out:
# 0.8629468177855275 0.017379154960018076
# 0.991869918699187 0.014423517739756543

# %%
addleft_scan_train_ave = np.mean([np.max(addleft_scan_train[i,:]) for i in range(n_runs)])
addleft_nacs_train_ave = np.mean([np.max(addleft_nacs_train[i,:]) for i in range(n_runs)])
addleft_scan_dev_ave = np.mean([np.max(addleft_scan_dev[i,:]) for i in range(n_runs)])
addleft_nacs_dev_ave = np.mean([np.max(addleft_nacs_dev[i,:]) for i in range(n_runs)])
addleft_scan_test_ave = np.mean([np.max(addleft_scan_test[i,:]) for i in range(n_runs)])
addleft_nacs_test_ave = np.mean([np.max(addleft_nacs_test[i,:]) for i in range(n_runs)])

# %%
addleft_scan_train_std = np.std([np.max(addleft_scan_train[i,:]) for i in range(n_runs)])
addleft_nacs_train_std = np.std([np.max(addleft_nacs_train[i,:]) for i in range(n_runs)])
addleft_scan_dev_std = np.std([np.max(addleft_scan_dev[i,:]) for i in range(n_runs)])
addleft_nacs_dev_std = np.std([np.max(addleft_nacs_dev[i,:]) for i in range(n_runs)])
addleft_scan_test_std = np.std([np.max(addleft_scan_test[i,:]) for i in range(n_runs)])
addleft_nacs_test_std = np.std([np.max(addleft_nacs_test[i,:]) for i in range(n_runs)])
train_std = [addleft_scan_train_std, addleft_nacs_train_std]
dev_std = [addleft_scan_dev_std, addleft_nacs_dev_std]
test_std = [addleft_scan_test_std, addleft_nacs_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[addleft_scan_train_ave,addleft_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[addleft_scan_dev_ave,addleft_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[addleft_scan_test_ave,addleft_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['left SCAN','left NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "left"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()
print(addleft_scan_test_ave, test_std[0])
print(addleft_nacs_test_ave, test_std[1])
# Out:
# 1.0 0.0
# 0.9993377483443708 0.0013245033112582849

# %%
length_scan_train_ave = np.mean([np.max(length_scan_train[i,:]) for i in range(n_runs)])
length_nacs_train_ave = np.mean([np.max(length_nacs_train[i,:]) for i in range(n_runs)])
length_scan_dev_ave = np.mean([np.max(length_scan_dev[i,:]) for i in range(n_runs)])
length_nacs_dev_ave = np.mean([np.max(length_nacs_dev[i,:]) for i in range(n_runs)])
length_scan_test_ave = np.mean([np.max(length_scan_test[i,:]) for i in range(n_runs)])
length_nacs_test_ave = np.mean([np.max(length_nacs_test[i,:]) for i in range(n_runs)])

# %%
length_scan_train_std = np.std([np.max(length_scan_train[i,:]) for i in range(n_runs)])
length_nacs_train_std = np.std([np.max(length_nacs_train[i,:]) for i in range(n_runs)])
length_scan_dev_std = np.std([np.max(length_scan_dev[i,:]) for i in range(n_runs)])
length_nacs_dev_std = np.std([np.max(length_nacs_dev[i,:]) for i in range(n_runs)])
length_scan_test_std = np.std([np.max(length_scan_test[i,:]) for i in range(n_runs)])
length_nacs_test_std = np.std([np.max(length_nacs_test[i,:]) for i in range(n_runs)])
train_std = [length_scan_train_std, length_nacs_train_std]
dev_std = [length_scan_dev_std, length_nacs_dev_std]
test_std = [length_scan_test_std, length_nacs_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[length_scan_train_ave,length_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[length_scan_dev_ave,length_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[length_scan_test_ave,length_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['length SCAN','length NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "length"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()
print(length_scan_test_ave, test_std[0])
print(length_nacs_test_ave, test_std[1])
# Out:
# 0.9166836734693877 0.06991091791092925
# 1.0 0.0

# %%
addjump_scan_train_ave = np.mean([np.max([item[0] for item in addjump_scan_train[i,:]]) for i in range(n_runs)])
addjump_nacs_train_ave = np.mean([np.max(addjump_nacs_train[i,:]) for i in range(n_runs)])
addjump_scan_dev_ave = np.mean([np.max([item[0] for item in addjump_scan_dev[i,:]]) for i in range(n_runs)])
addjump_nacs_dev_ave = np.mean([np.max(addjump_nacs_dev[i,:]) for i in range(n_runs)])
addjump_scan_test_ave = np.mean([np.max([item[0] for item in addjump_scan_test[i,:]]) for i in range(n_runs)])
addjump_nacs_test_ave = np.mean([np.max(addjump_nacs_test[i,:]) for i in range(n_runs)])

# %%
addjump_scan_train_std = np.std([np.max([item[0] for item in addjump_scan_train[i,:]]) for i in range(n_runs)])
addjump_nacs_train_std = np.std([np.max(addjump_nacs_train[i,:]) for i in range(n_runs)])
addjump_scan_dev_std = np.std([np.max([item[0] for item in addjump_scan_dev[i,:]]) for i in range(n_runs)])
addjump_nacs_dev_std = np.std([np.max(addjump_nacs_dev[i,:]) for i in range(n_runs)])
addjump_scan_test_std = np.std([np.max([item[0] for item in addjump_scan_test[i,:]]) for i in range(n_runs)])
addjump_nacs_test_std = np.std([np.max(addjump_nacs_test[i,:]) for i in range(n_runs)])
train_std = [addjump_scan_train_std, addjump_nacs_train_std]
dev_std = [addjump_scan_dev_std, addjump_nacs_dev_std]
test_std = [addjump_scan_test_std, addjump_nacs_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[addjump_scan_train_ave,addjump_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[addjump_scan_dev_ave,addjump_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[addjump_scan_test_ave,addjump_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['jump SCAN','jump NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "jump" 10 iters')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
addleft_removedleft_scan_train_ave = np.mean([np.max(addleft_removedleft_scan_train[i,:]) for i in range(n_runs)])
addleft_removedleft_nacs_train_ave = np.mean([np.max(addleft_removedleft_nacs_train[i,:]) for i in range(n_runs)])
addleft_removedleft_scan_dev_ave = np.mean([np.max(addleft_removedleft_scan_dev[i,:]) for i in range(n_runs)])
addleft_removedleft_nacs_dev_ave = np.mean([np.max(addleft_removedleft_nacs_dev[i,:]) for i in range(n_runs)])
addleft_removedleft_scan_test_ave = np.mean([np.max(addleft_removedleft_scan_test[i,:]) for i in range(n_runs)])
addleft_removedleft_nacs_test_ave = np.mean([np.max(addleft_removedleft_nacs_test[i,:]) for i in range(n_runs)])

# %%
addleft_removedleft_scan_train_std = np.std([np.max(addleft_removedleft_scan_train[i,:]) for i in range(n_runs)])
addleft_removedleft_nacs_train_std = np.std([np.max(addleft_removedleft_nacs_train[i,:]) for i in range(n_runs)])
addleft_removedleft_scan_dev_std = np.std([np.max(addleft_removedleft_scan_dev[i,:]) for i in range(n_runs)])
addleft_removedleft_nacs_dev_std = np.std([np.max(addleft_removedleft_nacs_dev[i,:]) for i in range(n_runs)])
addleft_removedleft_scan_test_std = np.std([np.max(addleft_removedleft_scan_test[i,:]) for i in range(n_runs)])
addleft_removedleft_nacs_test_std = np.std([np.max(addleft_removedleft_nacs_test[i,:]) for i in range(n_runs)])
train_std = [addleft_removedleft_scan_train_std, addleft_removedleft_nacs_train_std]
dev_std = [addleft_removedleft_scan_dev_std, addleft_removedleft_nacs_dev_std]
test_std = [addleft_removedleft_scan_test_std, addleft_removedleft_nacs_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[addleft_removedleft_scan_train_ave,addleft_removedleft_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[addleft_removedleft_scan_dev_ave,addleft_removedleft_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[addleft_removedleft_scan_test_ave,addleft_removedleft_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['turn left removed SCAN','turn left removed NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "turn left" removed')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()
print(addleft_removedleft_scan_test_ave, test_std[0])
print(addleft_removedleft_nacs_test_ave, test_std[1])
# Out:
# 1.0 0.0
# 0.9872516556291391 0.019558860166387235

# %%
addx_scan_train_ave = np.mean([np.max(addx_scan_train[i,:]) for i in range(n_runs)])
addx_nacs_train_ave = np.mean([np.max(addx_nacs_train[i,:]) for i in range(n_runs)])
addx_scan_dev_ave = np.mean([np.max(addx_scan_dev[i,:]) for i in range(n_runs)])
addx_nacs_dev_ave = np.mean([np.max(addx_nacs_dev[i,:]) for i in range(n_runs)])
addx_scan_test_ave = np.mean([np.max(addx_scan_test[i,:]) for i in range(n_runs)])
addx_nacs_test_ave = np.mean([np.max(addx_nacs_test[i,:]) for i in range(n_runs)])

# %%
addx_scan_train_std = np.std([np.max(addx_scan_train[i,:]) for i in range(n_runs)])
addx_nacs_train_std = np.std([np.max(addx_nacs_train[i,:]) for i in range(n_runs)])
addx_scan_dev_std = np.std([np.max(addx_scan_dev[i,:]) for i in range(n_runs)])
addx_nacs_dev_std = np.std([np.max(addx_nacs_dev[i,:]) for i in range(n_runs)])
addx_scan_test_std = np.std([np.max(addx_scan_test[i,:]) for i in range(n_runs)])
addx_nacs_test_std = np.std([np.max(addx_nacs_test[i,:]) for i in range(n_runs)])
train_std = [addx_scan_train_std, addx_nacs_train_std]
dev_std = [addx_scan_dev_std, addx_nacs_dev_std]
test_std = [addx_scan_test_std, addx_nacs_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[addx_scan_train_ave,addx_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[addx_scan_dev_ave,addx_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[addx_scan_test_ave,addx_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['turn x SCAN','turn x NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "turn x" 10 iters')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
addjump_scan_secondrun_train_ave = np.mean([np.max(addjump_scan_secondrun_train[i,:]) for i in range(n_runs)])
addjump_nacs_secondrun_train_ave = np.mean([np.max(addjump_nacs_secondrun_train[i,:]) for i in range(n_runs)])
addjump_scan_secondrun_dev_ave = np.mean([np.max(addjump_scan_secondrun_dev[i,:]) for i in range(n_runs)])
addjump_nacs_secondrun_dev_ave = np.mean([np.max(addjump_nacs_secondrun_dev[i,:]) for i in range(n_runs)])
addjump_scan_secondrun_test_ave = np.mean([np.max(addjump_scan_secondrun_test[i,:]) for i in range(n_runs)])
addjump_nacs_secondrun_test_ave = np.mean([np.max(addjump_nacs_secondrun_test[i,:]) for i in range(n_runs)])

# %%
addjump_scan_secondrun_train_std = np.std([np.max(addjump_scan_secondrun_train[i,:]) for i in range(n_runs)])
addjump_nacs_secondrun_train_std = np.std([np.max(addjump_nacs_secondrun_train[i,:]) for i in range(n_runs)])
addjump_scan_secondrun_dev_std = np.std([np.max(addjump_scan_secondrun_dev[i,:]) for i in range(n_runs)])
addjump_nacs_secondrun_dev_std = np.std([np.max(addjump_nacs_secondrun_dev[i,:]) for i in range(n_runs)])
addjump_scan_secondrun_test_std = np.std([np.max(addjump_scan_secondrun_test[i,:]) for i in range(n_runs)])
addjump_nacs_secondrun_test_std = np.std([np.max(addjump_nacs_secondrun_test[i,:]) for i in range(n_runs)])
train_std = [addjump_scan_secondrun_train_std, addjump_nacs_secondrun_train_std]
dev_std = [addjump_scan_secondrun_dev_std, addjump_nacs_secondrun_dev_std]
test_std = [addjump_scan_secondrun_test_std, addjump_nacs_secondrun_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[addjump_scan_secondrun_train_ave,addjump_nacs_secondrun_train_ave],yerr=train_std,width=w)
plt.bar(c,[addjump_scan_secondrun_dev_ave,addjump_nacs_secondrun_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[addjump_scan_secondrun_test_ave,addjump_nacs_secondrun_test_ave],yerr=test_std,width=w)
plt.xticks(c,['addjump_scan_secondrun','addjump_nacs_secondrun'])
plt.ylabel('Accuracy')
plt.title('Performance')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
addx_scan_secondrun_train_ave = np.mean([np.max(addx_scan_secondrun_train[i,:]) for i in range(n_runs)])
addx_nacs_secondrun_train_ave = np.mean([np.max(addx_nacs_secondrun_train[i,:]) for i in range(n_runs)])
addx_scan_secondrun_dev_ave = np.mean([np.max(addx_scan_secondrun_dev[i,:]) for i in range(n_runs)])
addx_nacs_secondrun_dev_ave = np.mean([np.max(addx_nacs_secondrun_dev[i,:]) for i in range(n_runs)])
addx_scan_secondrun_test_ave = np.mean([np.max(addx_scan_secondrun_test[i,:]) for i in range(n_runs)])
addx_nacs_secondrun_test_ave = np.mean([np.max(addx_nacs_secondrun_test[i,:]) for i in range(n_runs)])

# %%
addx_scan_secondrun_train_std = np.std([np.max(addx_scan_secondrun_train[i,:]) for i in range(n_runs)])
addx_nacs_secondrun_train_std = np.std([np.max(addx_nacs_secondrun_train[i,:]) for i in range(n_runs)])
addx_scan_secondrun_dev_std = np.std([np.max(addx_scan_secondrun_dev[i,:]) for i in range(n_runs)])
addx_nacs_secondrun_dev_std = np.std([np.max(addx_nacs_secondrun_dev[i,:]) for i in range(n_runs)])
addx_scan_secondrun_test_std = np.std([np.max(addx_scan_secondrun_test[i,:]) for i in range(n_runs)])
addx_nacs_secondrun_test_std = np.std([np.max(addx_nacs_secondrun_test[i,:]) for i in range(n_runs)])
train_std = [addx_scan_secondrun_train_std, addx_nacs_secondrun_train_std]
dev_std = [addx_scan_secondrun_dev_std, addx_nacs_secondrun_dev_std]
test_std = [addx_scan_secondrun_test_std, addx_nacs_secondrun_test_std]

# %%
c = np.array([0,1])
w = 0.3

plt.bar(c-w,[addx_scan_secondrun_train_ave,addx_nacs_secondrun_train_ave],yerr=train_std,width=w)
plt.bar(c,[addx_scan_secondrun_dev_ave,addx_nacs_secondrun_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[addx_scan_secondrun_test_ave,addx_nacs_secondrun_test_ave],yerr=test_std,width=w)
plt.xticks(c,['addx_scan_secondrun','addx_nacs_secondrun'])
plt.ylabel('Accuracy')
plt.title('Performance')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
split1_scan_train_ave = np.mean([np.max([item[0] for item in split1_scan_train[i]]) for i in range(n_runs)])
split1_scan_dev_ave = np.mean([np.max([item[0] for item in split1_scan_dev[i]]) for i in range(n_runs)])
split1_scan_test_ave = np.mean([np.max([item[0] for item in split1_scan_test[i]]) for i in range(n_runs)])
split1_nacs_train_ave = np.mean([np.max(split1_nacs_train[i,:]) for i in range(n_runs)])
split1_nacs_dev_ave = np.mean([np.max(split1_nacs_dev[i,:]) for i in range(n_runs)])
split1_nacs_test_ave = np.mean([np.max(split1_nacs_test[i,:]) for i in range(n_runs)])

# %%
split1_scan_train_std = np.std([np.max([item[0] for item in split1_scan_train[i]]) for i in range(n_runs)])
split1_scan_dev_std = np.std([np.max([item[0] for item in split1_scan_dev[i]]) for i in range(n_runs)])
split1_scan_test_std = np.std([np.max([item[0] for item in split1_scan_test[i]]) for i in range(n_runs)])
split1_nacs_train_std = np.std([np.max(split1_nacs_train[i,:]) for i in range(n_runs)])
split1_nacs_dev_std = np.std([np.max(split1_nacs_dev[i,:]) for i in range(n_runs)])
split1_nacs_test_std = np.std([np.max(split1_nacs_test[i,:]) for i in range(n_runs)])
train_std = [split1_scan_train_std, split1_nacs_train_std]
dev_std = [split1_scan_dev_std, split1_nacs_dev_std]
test_std = [split1_scan_test_std, split1_nacs_test_std]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[split1_scan_train_ave, split1_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[split1_scan_dev_ave, split1_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[split1_scan_test_ave, split1_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['split1 SCAN', 'split1 NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "split1" 10 iters')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
split2_scan_train_ave = np.mean([np.max(split2_scan_train[i,:]) for i in range(n_runs)])
split2_scan_dev_ave = np.mean([np.max(split2_scan_dev[i,:]) for i in range(n_runs)])
split2_scan_test_ave = np.mean([np.max(split2_scan_test[i,:]) for i in range(n_runs)])
split2_nacs_train_ave = np.mean([np.max(split2_nacs_train[i,:]) for i in range(n_runs)])
split2_nacs_dev_ave = np.mean([np.max(split2_nacs_dev[i,:]) for i in range(n_runs)])
split2_nacs_test_ave = np.mean([np.max(split2_nacs_test[i,:]) for i in range(n_runs)])

# %%
split2_scan_train_std = np.std([np.max(split2_scan_train[i,:]) for i in range(n_runs)])
split2_scan_dev_std = np.std([np.max(split2_scan_dev[i,:]) for i in range(n_runs)])
split2_scan_test_std = np.std([np.max(split2_scan_test[i,:]) for i in range(n_runs)])
split2_nacs_train_std = np.std([np.max(split2_nacs_train[i,:]) for i in range(n_runs)])
split2_nacs_dev_std = np.std([np.max(split2_nacs_dev[i,:]) for i in range(n_runs)])
split2_nacs_test_std = np.std([np.max(split2_nacs_test[i,:]) for i in range(n_runs)])
train_std = [split2_scan_train_std, split2_nacs_train_std]
dev_std = [split2_scan_dev_std, split2_nacs_dev_std]
test_std = [split2_scan_test_std, split2_nacs_test_std]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[split2_scan_train_ave, split2_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[split2_scan_dev_ave, split2_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[split2_scan_test_ave, split2_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['split2 SCAN', 'split2 NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "split2" 10 iters')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
jumpo_scan_train_ave = np.mean([np.max([item[0] for item in jumpo_scan_train[i]]) for i in range(n_runs)])
jumpo_scan_dev_ave = np.mean([np.max([item[0] for item in jumpo_scan_dev[i]]) for i in range(n_runs)])
jumpo_scan_test_ave = np.mean([np.max([item[0] for item in jumpo_scan_test[i]]) for i in range(n_runs)])
jumpo_nacs_train_ave = np.mean([np.max(jumpo_nacs_train[i,:]) for i in range(n_runs)])
jumpo_nacs_dev_ave = np.mean([np.max(jumpo_nacs_dev[i,:]) for i in range(n_runs)])
jumpo_nacs_test_ave = np.mean([np.max(jumpo_nacs_test[i,:]) for i in range(n_runs)])

# %%
jumpo_scan_train_std = np.std([np.max([item[0] for item in jumpo_scan_train[i]]) for i in range(n_runs)])
jumpo_scan_dev_std = np.std([np.max([item[0] for item in jumpo_scan_dev[i]]) for i in range(n_runs)])
jumpo_scan_test_std = np.std([np.max([item[0] for item in jumpo_scan_test[i]]) for i in range(n_runs)])
jumpo_nacs_train_std = np.std([np.max(jumpo_nacs_train[i,:]) for i in range(n_runs)])
jumpo_nacs_dev_std = np.std([np.max(jumpo_nacs_dev[i,:]) for i in range(n_runs)])
jumpo_nacs_test_std = np.std([np.max(jumpo_nacs_test[i,:]) for i in range(n_runs)])
train_std = [jumpo_scan_train_std, jumpo_nacs_train_std]
dev_std = [jumpo_scan_dev_std, jumpo_nacs_dev_std]
test_std = [jumpo_scan_test_std, jumpo_nacs_test_std]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[jumpo_scan_train_ave, jumpo_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[jumpo_scan_dev_ave, jumpo_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[jumpo_scan_test_ave, jumpo_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['-o SCAN', '-o NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "-o" 10 iters')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
uniquesuffix_scan_train_ave = np.mean([np.max(uniquesuffix_scan_train[i,:]) for i in range(n_runs)])
uniquesuffix_scan_dev_ave = np.mean([np.max(uniquesuffix_scan_dev[i,:]) for i in range(n_runs)])
uniquesuffix_scan_test_ave = np.mean([np.max(uniquesuffix_scan_test[i,:]) for i in range(n_runs)])
uniquesuffix_nacs_train_ave = np.mean([np.max(uniquesuffix_nacs_train[i,:]) for i in range(n_runs)])
uniquesuffix_nacs_dev_ave = np.mean([np.max(uniquesuffix_nacs_dev[i,:]) for i in range(n_runs)])
uniquesuffix_nacs_test_ave = np.mean([np.max(uniquesuffix_nacs_test[i,:]) for i in range(n_runs)])

# %%
uniquesuffix_scan_train_std = np.std([np.max(uniquesuffix_scan_train[i,:]) for i in range(n_runs)])
uniquesuffix_scan_dev_std = np.std([np.max(uniquesuffix_scan_dev[i,:]) for i in range(n_runs)])
uniquesuffix_scan_test_std = np.std([np.max(uniquesuffix_scan_test[i,:]) for i in range(n_runs)])
uniquesuffix_nacs_train_std = np.std([np.max(uniquesuffix_nacs_train[i,:]) for i in range(n_runs)])
uniquesuffix_nacs_dev_std = np.std([np.max(uniquesuffix_nacs_dev[i,:]) for i in range(n_runs)])
uniquesuffix_nacs_test_std = np.std([np.max(uniquesuffix_nacs_test[i,:]) for i in range(n_runs)])
train_std = [uniquesuffix_scan_train_std, uniquesuffix_nacs_train_std]
dev_std = [uniquesuffix_scan_dev_std, uniquesuffix_nacs_dev_std]
test_std = [uniquesuffix_scan_test_std, uniquesuffix_nacs_test_std]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[uniquesuffix_scan_train_ave, uniquesuffix_nacs_train_ave],yerr=train_std,width=w)
plt.bar(c,[uniquesuffix_scan_dev_ave, uniquesuffix_nacs_dev_ave],yerr=dev_std,width=w)
plt.bar(c+w,[uniquesuffix_scan_test_ave, uniquesuffix_nacs_test_ave],yerr=test_std,width=w)
plt.xticks(c,['unique suffix SCAN', 'unique suffix NACS'])
plt.ylabel('Accuracy')
plt.title('Performance "unique suffix" 10 iters')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
np.mean([np.max(addx_nacs_test[i,:]) for i in range(n_runs)])
# Out:
# 0.5094370860927152

# %%
np.mean([np.max(addjump_nacs_test[i,:]) for i in range(n_runs)])
# Out:
# 0.3098883986504023

# %%
np.mean([np.max(addjump_scan_test[i,:]) for i in range(n_runs)])
# Out:
# 0.6444744016057038

# %%
np.mean([np.max(addx_scan_test[i,:]) for i in range(n_runs)])
# Out:
# 0.11026490066225166

# %%
print(addjump_scan_test_std)
print(addx_scan_test_std)
print(addjump_nacs_test_std)
print(addx_nacs_test_std)
# Out:
# 0.04868124485996993
# 0.12305501862175167
# 0.3579322354742788
# 0.3233056693793251

# %%
#Flattens the 2d array to 1d to get raw results of every epoch:
Accuracy_2epochs = addleft_removedleft_scan_test.flatten()

#Sets n to (the amount of runs) * (numper of epochs) and makes 
n = n_runs*2
c = np.linspace(1,100,n)
H = np.linspace(0,1,n+1)
Count = np.zeros([n])

#Count the number of measurements that fall within a 0.1 range.
for i in range(n):
    for j in range(n):
        if H[j] <= Accuracy_2epochs[i] <= H[j+1]:
            Count[j] = Count[j]+1
            
#plot
figure(figsize=(8, 6), dpi=100)
plt.bar(c-1,Count)
plt.xlabel('Accuracy')
plt.ylabel('Count (N=20)')
plt.title('addjump_nacs')
plt.show()
