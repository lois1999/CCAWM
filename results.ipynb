# %% [markdown]
# # Results of experiments with transformer models on SCAN and NACS

# %%
import json
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# %% [markdown]
# ## Load all data into numpy array

# %%
def load_runs(results_path,n_runs):
    losses = []
    train_accs = []
    dev_accs = []
    test_accs = []
    for run in range(n_runs):
        fn = results_path + str(run) + '.json'
        with open(fn,'r') as f:
            results = json.load(f)
        losses.append(results['loss_data'])
        train_accs.append(results['train_accs'])
        dev_accs.append(results['dev_accs'])
        test_accs.append(results['test_accs'])
    losses = np.array(losses)
    train_accs = np.array(train_accs)
    dev_accs = np.array(dev_accs)
    test_accs = np.array(test_accs)
    return losses, train_accs, dev_accs, test_accs

# %%
n_runs = 10

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/simple_scan'
simple_scan_losses, simple_scan_train, simple_scan_dev, simple_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addleft_scan'
addleft_scan_losses, addleft_scan_train, addleft_scan_dev, addleft_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addjump_scan'
addjump_scan_losses, addjump_scan_train, addjump_scan_dev, addjump_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addleft_removedleft_scan'
addleft_removedleft_scan_losses, addleft_removedleft_scan_train, addleft_removedleft_scan_dev, addleft_removedleft_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/addx_scan'
addx_scan_losses, addx_scan_train, addx_scan_dev, addx_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/churny_scan'
churny_scan_losses, churny_scan_train, churny_scan_dev, churny_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/split1_scan'
split1_scan_losses, split1_scan_train, split1_scan_dev, split1_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/split2_scan'
split2_scan_losses, split2_scan_train, split2_scan_dev, split2_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/jumpo_scan'
jumpo_scan_losses, jumpo_scan_train, jumpo_scan_dev, jumpo_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/uniquesuffix_scan'
uniquesuffix_scan_losses, uniquesuffix_scan_train, uniquesuffix_scan_dev, uniquesuffix_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/simplesplit1_scan'
simplesplit1_scan_losses, simplesplit1_scan_train, simplesplit1_scan_dev, simplesplit1_scan_test = load_runs(results_path,n_runs)

# %%
results_path = '/home/lois/Documents/Master AI UU/Cognitive and Computational Aspects of Word Meaning/Compositional-generalization-capabillity-of-Transformer/results/transformer/verbarg_scan'
verbarg_scan_losses, verbarg_scan_train, verbarg_scan_dev, verbarg_scan_test = load_runs(results_path,n_runs)

# %% [markdown]
# ## Plot losses

# %%
simple_scan_losses_ave = np.mean(simple_scan_losses,axis=0)
plt.plot(simple_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Simple SCAN')
plt.ylim([0,3.5])
plt.show()
print(len(simple_scan_losses_ave))
# Out:
# 132

# %%
addjump_scan_losses_ave = np.mean(addjump_scan_losses,axis=0)
plt.plot(addjump_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Jump SCAN')
plt.ylim([0,3.5])
plt.show()
print(len(addjump_scan_losses_ave))
# Out:
# 120

# %%
addleft_removedleft_scan_losses_ave = np.mean(addleft_removedleft_scan_losses,axis=0)
plt.plot(addleft_removedleft_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Turn left removed SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
addx_scan_losses_ave = np.mean(addx_scan_losses,axis=0)
plt.plot(addx_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Turn x SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
churny_scan_losses_ave = np.mean(churny_scan_losses,axis=0)
plt.plot(churny_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Churn y SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
split1_scan_losses_ave = np.mean(split1_scan_losses,axis=0)
plt.plot(split1_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Split 1 SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
split2_scan_losses_ave = np.mean(split2_scan_losses,axis=0)
plt.plot(split2_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Split 2 SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
jumpo_scan_losses_ave = np.mean(jumpo_scan_losses,axis=0)
plt.plot(jumpo_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve -o SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
uniquesuffix_scan_losses_ave = np.mean(uniquesuffix_scan_losses,axis=0)
plt.plot(uniquesuffix_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Unique suffix SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
simplesplit1_scan_losses_ave = np.mean(simplesplit1_scan_losses,axis=0)
plt.plot(simplesplit1_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Simple split 1 SCAN')
plt.ylim([0,3.5])
plt.show()

# %%
verbarg_scan_losses_ave = np.mean(verbarg_scan_losses,axis=0)
plt.plot(verbarg_scan_losses_ave)
plt.xlabel('Iteration (batch size = 64)')
plt.ylabel('Cross entropy loss')
plt.title('Training curve Argument based SCAN')
plt.ylim([0,3.5])
plt.show()

# %% [markdown]
# ## Plot accuracies

# %%
simple_scan_train_ave = np.mean([np.max([item[1] for item in simple_scan_train[i]]) for i in range(n_runs)])
simple_scan_train_ave_string = np.mean([np.max([item[0] for item in simple_scan_train[i]]) for i in range(n_runs)])
simple_scan_dev_ave = np.mean([np.max([item[1] for item in simple_scan_dev[i]]) for i in range(n_runs)])
simple_scan_dev_ave_string = np.mean([np.max([item[0] for item in simple_scan_dev[i]]) for i in range(n_runs)])
simple_scan_test_ave = np.mean([np.max([item[1] for item in simple_scan_test[i]]) for i in range(n_runs)])
simple_scan_test_ave_string = np.mean([np.max([item[0] for item in simple_scan_test[i]]) for i in range(n_runs)])

# %%
simple_scan_train_std = np.std([np.max([item[1] for item in simple_scan_train[i]]) for i in range(n_runs)])
simple_scan_train_std_string = np.std([np.max([item[0] for item in simple_scan_train[i]]) for i in range(n_runs)])
simple_scan_dev_std = np.std([np.max([item[1] for item in simple_scan_dev[i]]) for i in range(n_runs)])
simple_scan_dev_std_string = np.std([np.max([item[0] for item in simple_scan_dev[i]]) for i in range(n_runs)])
simple_scan_test_std = np.std([np.max([item[1] for item in simple_scan_test[i]]) for i in range(n_runs)])
simple_scan_test_std_string = np.std([np.max([item[0] for item in simple_scan_test[i]]) for i in range(n_runs)])
train_std = [simple_scan_train_std, simple_scan_train_std_string]
dev_std = [simple_scan_dev_std, simple_scan_dev_std_string]
test_std = [simple_scan_test_std, simple_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[simple_scan_train_ave,simple_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[simple_scan_dev_ave,simple_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[simple_scan_test_ave,simple_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy','string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "simple"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
addjump_scan_train_ave = np.mean([np.max([item[1] for item in addjump_scan_train[i]]) for i in range(n_runs)])
addjump_scan_train_ave_string = np.mean([np.max([item[0] for item in addjump_scan_train[i]]) for i in range(n_runs)])
addjump_scan_dev_ave = np.mean([np.max([item[1] for item in addjump_scan_dev[i]]) for i in range(n_runs)])
addjump_scan_dev_ave_string = np.mean([np.max([item[0] for item in addjump_scan_dev[i]]) for i in range(n_runs)])
addjump_scan_test_ave = np.mean([np.max([item[1] for item in addjump_scan_test[i]]) for i in range(n_runs)])
addjump_scan_test_ave_string = np.mean([np.max([item[0] for item in addjump_scan_test[i]]) for i in range(n_runs)])

# %%
addjump_scan_train_std = np.std([np.max([item[1] for item in addjump_scan_train[i]]) for i in range(n_runs)])
addjump_scan_train_std_string = np.std([np.max([item[0] for item in addjump_scan_train[i]]) for i in range(n_runs)])
addjump_scan_dev_std = np.std([np.max([item[1] for item in addjump_scan_dev[i]]) for i in range(n_runs)])
addjump_scan_dev_std_string = np.std([np.max([item[0] for item in addjump_scan_dev[i]]) for i in range(n_runs)])
addjump_scan_test_std = np.std([np.max([item[1] for item in addjump_scan_test[i]]) for i in range(n_runs)])
addjump_scan_test_std_string = np.std([np.max([item[0] for item in addjump_scan_test[i]]) for i in range(n_runs)])
train_std = [addjump_scan_train_std, addjump_scan_train_std_string]
dev_std = [addjump_scan_dev_std, addjump_scan_dev_std_string]
test_std = [addjump_scan_test_std, addjump_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[addjump_scan_train_ave,addjump_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[addjump_scan_dev_ave,addjump_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[addjump_scan_test_ave,addjump_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy','string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "jump"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
addleft_removedleft_scan_train_ave = np.mean([np.max([item[1] for item in addleft_removedleft_scan_train[i]]) for i in range(n_runs)])
addleft_removedleft_scan_train_ave_string = np.mean([np.max([item[0] for item in addleft_removedleft_scan_train[i]]) for i in range(n_runs)])
addleft_removedleft_scan_dev_ave = np.mean([np.max([item[1] for item in addleft_removedleft_scan_dev[i]]) for i in range(n_runs)])
addleft_removedleft_scan_dev_ave_string = np.mean([np.max([item[0] for item in addleft_removedleft_scan_dev[i]]) for i in range(n_runs)])
addleft_removedleft_scan_test_ave = np.mean([np.max([item[1] for item in addleft_removedleft_scan_test[i]]) for i in range(n_runs)])
addleft_removedleft_scan_test_ave_string = np.mean([np.max([item[0] for item in addleft_removedleft_scan_test[i]]) for i in range(n_runs)])

# %%
addleft_removedleft_scan_train_std = np.std([np.max([item[1] for item in addleft_removedleft_scan_train[i]]) for i in range(n_runs)])
addleft_removedleft_scan_train_std_string = np.std([np.max([item[0] for item in addleft_removedleft_scan_train[i]]) for i in range(n_runs)])
addleft_removedleft_scan_dev_std = np.std([np.max([item[1] for item in addleft_removedleft_scan_dev[i]]) for i in range(n_runs)])
addleft_removedleft_scan_dev_std_string = np.std([np.max([item[0] for item in addleft_removedleft_scan_dev[i]]) for i in range(n_runs)])
addleft_removedleft_scan_test_std = np.std([np.max([item[1] for item in addleft_removedleft_scan_test[i]]) for i in range(n_runs)])
addleft_removedleft_scan_test_std_string = np.std([np.max([item[0] for item in addleft_removedleft_scan_test[i]]) for i in range(n_runs)])
train_std = [addleft_removedleft_scan_train_std, addleft_removedleft_scan_train_std_string]
dev_std = [addleft_removedleft_scan_dev_std, addleft_removedleft_scan_dev_std_string]
test_std = [addleft_removedleft_scan_test_std, addleft_removedleft_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[addleft_removedleft_scan_train_ave,addleft_removedleft_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[addleft_removedleft_scan_dev_ave,addleft_removedleft_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[addleft_removedleft_scan_test_ave,addleft_removedleft_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy','string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "turn left" removed')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
addx_scan_train_ave = np.mean([np.max([item[1] for item in addx_scan_train[i]]) for i in range(n_runs)])
addx_scan_train_ave_string = np.mean([np.max([item[0] for item in addx_scan_train[i]]) for i in range(n_runs)])
addx_scan_dev_ave = np.mean([np.max([item[1] for item in addx_scan_dev[i]]) for i in range(n_runs)])
addx_scan_dev_ave_string = np.mean([np.max([item[0] for item in addx_scan_dev[i]]) for i in range(n_runs)])
addx_scan_test_ave = np.mean([np.max([item[1] for item in addx_scan_test[i]]) for i in range(n_runs)])
addx_scan_test_ave_string = np.mean([np.max([item[0] for item in addx_scan_test[i]]) for i in range(n_runs)])

# %%
addx_scan_train_std = np.std([np.max([item[1] for item in addx_scan_train[i]]) for i in range(n_runs)])
addx_scan_train_std_string = np.std([np.max([item[0] for item in addx_scan_train[i]]) for i in range(n_runs)])
addx_scan_dev_std = np.std([np.max([item[1] for item in addx_scan_dev[i]]) for i in range(n_runs)])
addx_scan_dev_std_string = np.std([np.max([item[0] for item in addx_scan_dev[i]]) for i in range(n_runs)])
addx_scan_test_std = np.std([np.max([item[1] for item in addx_scan_test[i]]) for i in range(n_runs)])
addx_scan_test_std_string = np.std([np.max([item[0] for item in addx_scan_test[i]]) for i in range(n_runs)])
train_std = [addx_scan_train_std, addx_scan_train_std_string]
dev_std = [addx_scan_dev_std, addx_scan_dev_std_string]
test_std = [addx_scan_test_std, addx_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[addx_scan_train_ave,addx_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[addx_scan_dev_ave,addx_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[addx_scan_test_ave,addx_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy','string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "turn x"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
churny_scan_train_ave = np.mean([np.max([item[1] for item in churny_scan_train[i]]) for i in range(n_runs)])
churny_scan_train_ave_string = np.mean([np.max([item[0] for item in churny_scan_train[i]]) for i in range(n_runs)])
churny_scan_dev_ave = np.mean([np.max([item[1] for item in churny_scan_dev[i]]) for i in range(n_runs)])
churny_scan_dev_ave_string = np.mean([np.max([item[0] for item in churny_scan_dev[i]]) for i in range(n_runs)])
churny_scan_test_ave = np.mean([np.max([item[1] for item in churny_scan_test[i]]) for i in range(n_runs)])
churny_scan_test_ave_string = np.mean([np.max([item[0] for item in churny_scan_test[i]]) for i in range(n_runs)])

# %%
churny_scan_train_std = np.std([np.max([item[1] for item in churny_scan_train[i]]) for i in range(n_runs)])
churny_scan_train_std_string = np.std([np.max([item[0] for item in churny_scan_train[i]]) for i in range(n_runs)])
churny_scan_dev_std = np.std([np.max([item[1] for item in churny_scan_dev[i]]) for i in range(n_runs)])
churny_scan_dev_std_string = np.std([np.max([item[0] for item in churny_scan_dev[i]]) for i in range(n_runs)])
churny_scan_test_std = np.std([np.max([item[1] for item in churny_scan_test[i]]) for i in range(n_runs)])
churny_scan_test_std_string = np.std([np.max([item[0] for item in churny_scan_test[i]]) for i in range(n_runs)])
train_std = [churny_scan_train_std, churny_scan_train_std_string]
dev_std = [churny_scan_dev_std, churny_scan_dev_std_string]
test_std = [churny_scan_test_std, churny_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[churny_scan_train_ave,churny_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[churny_scan_dev_ave,churny_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[churny_scan_test_ave,churny_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy','string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "churn y"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
split1_scan_train_ave = np.mean([np.max([item[1] for item in split1_scan_train[i]]) for i in range(n_runs)])
split1_scan_dev_ave = np.mean([np.max([item[1] for item in split1_scan_dev[i]]) for i in range(n_runs)])
split1_scan_test_ave = np.mean([np.max([item[1] for item in split1_scan_test[i]]) for i in range(n_runs)])
split1_scan_train_ave_string = np.mean([np.max([item[0] for item in split1_scan_train[i]]) for i in range(n_runs)])
split1_scan_dev_ave_string = np.mean([np.max([item[0] for item in split1_scan_dev[i]]) for i in range(n_runs)])
split1_scan_test_ave_string = np.mean([np.max([item[0] for item in split1_scan_test[i]]) for i in range(n_runs)])

# %%
split1_scan_train_std = np.std([np.max([item[1] for item in split1_scan_train[i]]) for i in range(n_runs)])
split1_scan_dev_std = np.std([np.max([item[1] for item in split1_scan_dev[i]]) for i in range(n_runs)])
split1_scan_test_std = np.std([np.max([item[1] for item in split1_scan_test[i]]) for i in range(n_runs)])
split1_scan_train_std_string = np.std([np.max([item[0] for item in split1_scan_train[i]]) for i in range(n_runs)])
split1_scan_dev_std_string = np.std([np.max([item[0] for item in split1_scan_dev[i]]) for i in range(n_runs)])
split1_scan_test_std_string = np.std([np.max([item[0] for item in split1_scan_test[i]]) for i in range(n_runs)])
train_std = [split1_scan_train_std, split1_scan_train_std_string]
dev_std = [split1_scan_dev_std, split1_scan_dev_std_string]
test_std = [split1_scan_test_std, split1_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[split1_scan_train_ave, split1_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[split1_scan_dev_ave, split1_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[split1_scan_test_ave, split1_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy', 'string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "split 1"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
split2_scan_train_ave = np.mean([np.max([item[1] for item in split2_scan_train[i]]) for i in range(n_runs)])
split2_scan_dev_ave = np.mean([np.max([item[1] for item in split2_scan_dev[i]]) for i in range(n_runs)])
split2_scan_test_ave = np.mean([np.max([item[1] for item in split2_scan_test[i]]) for i in range(n_runs)])
split2_scan_train_ave_string = np.mean([np.max([item[0] for item in split2_scan_train[i]]) for i in range(n_runs)])
split2_scan_dev_ave_string = np.mean([np.max([item[0] for item in split2_scan_dev[i]]) for i in range(n_runs)])
split2_scan_test_ave_string = np.mean([np.max([item[0] for item in split2_scan_test[i]]) for i in range(n_runs)])

# %%
split2_scan_train_std = np.std([np.max([item[1] for item in split2_scan_train[i]]) for i in range(n_runs)])
split2_scan_dev_std = np.std([np.max([item[1] for item in split2_scan_dev[i]]) for i in range(n_runs)])
split2_scan_test_std = np.std([np.max([item[1] for item in split2_scan_test[i]]) for i in range(n_runs)])
split2_scan_train_std_string = np.std([np.max([item[0] for item in split2_scan_train[i]]) for i in range(n_runs)])
split2_scan_dev_std_string = np.std([np.max([item[0] for item in split2_scan_dev[i]]) for i in range(n_runs)])
split2_scan_test_std_string = np.std([np.max([item[0] for item in split2_scan_test[i]]) for i in range(n_runs)])
train_std = [split2_scan_train_std, split2_scan_train_std_string]
dev_std = [split2_scan_dev_std, split2_scan_dev_std_string]
test_std = [split2_scan_test_std, split2_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[split2_scan_train_ave, split2_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[split2_scan_dev_ave, split2_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[split2_scan_test_ave, split2_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy', 'string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "split 2"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
jumpo_scan_train_ave = np.mean([np.max([item[1] for item in jumpo_scan_train[i]]) for i in range(n_runs)])
jumpo_scan_dev_ave = np.mean([np.max([item[1] for item in jumpo_scan_dev[i]]) for i in range(n_runs)])
jumpo_scan_test_ave = np.mean([np.max([item[1] for item in jumpo_scan_test[i]]) for i in range(n_runs)])
jumpo_scan_train_ave_string = np.mean([np.max([item[0] for item in jumpo_scan_train[i]]) for i in range(n_runs)])
jumpo_scan_dev_ave_string = np.mean([np.max([item[0] for item in jumpo_scan_dev[i]]) for i in range(n_runs)])
jumpo_scan_test_ave_string = np.mean([np.max([item[0] for item in jumpo_scan_test[i]]) for i in range(n_runs)])

# %%
jumpo_scan_train_std = np.std([np.max([item[1] for item in jumpo_scan_train[i]]) for i in range(n_runs)])
jumpo_scan_dev_std = np.std([np.max([item[1] for item in jumpo_scan_dev[i]]) for i in range(n_runs)])
jumpo_scan_test_std = np.std([np.max([item[1] for item in jumpo_scan_test[i]]) for i in range(n_runs)])
jumpo_scan_train_std_string = np.std([np.max([item[0] for item in jumpo_scan_train[i]]) for i in range(n_runs)])
jumpo_scan_dev_std_string = np.std([np.max([item[0] for item in jumpo_scan_dev[i]]) for i in range(n_runs)])
jumpo_scan_test_std_string = np.std([np.max([item[0] for item in jumpo_scan_test[i]]) for i in range(n_runs)])
train_std = [jumpo_scan_train_std, jumpo_scan_train_std_string]
dev_std = [jumpo_scan_dev_std, jumpo_scan_dev_std_string]
test_std = [jumpo_scan_test_std, jumpo_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[jumpo_scan_train_ave, jumpo_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[jumpo_scan_dev_ave, jumpo_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[jumpo_scan_test_ave, jumpo_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy', 'string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "-o"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
uniquesuffix_scan_train_ave = np.mean([np.max([item[1] for item in uniquesuffix_scan_train[i]]) for i in range(n_runs)])
uniquesuffix_scan_dev_ave = np.mean([np.max([item[1] for item in uniquesuffix_scan_dev[i]]) for i in range(n_runs)])
uniquesuffix_scan_test_ave = np.mean([np.max([item[1] for item in uniquesuffix_scan_test[i]]) for i in range(n_runs)])
uniquesuffix_scan_train_ave_string = np.mean([np.max([item[0] for item in uniquesuffix_scan_train[i]]) for i in range(n_runs)])
uniquesuffix_scan_dev_ave_string = np.mean([np.max([item[0] for item in uniquesuffix_scan_dev[i]]) for i in range(n_runs)])
uniquesuffix_scan_test_ave_string = np.mean([np.max([item[0] for item in uniquesuffix_scan_test[i]]) for i in range(n_runs)])

# %%
uniquesuffix_scan_train_std = np.std([np.max([item[1] for item in uniquesuffix_scan_train[i]]) for i in range(n_runs)])
uniquesuffix_scan_dev_std = np.std([np.max([item[1] for item in uniquesuffix_scan_dev[i]]) for i in range(n_runs)])
uniquesuffix_scan_test_std = np.std([np.max([item[1] for item in uniquesuffix_scan_test[i]]) for i in range(n_runs)])
uniquesuffix_scan_train_std_string = np.std([np.max([item[0] for item in uniquesuffix_scan_train[i]]) for i in range(n_runs)])
uniquesuffix_scan_dev_std_string = np.std([np.max([item[0] for item in uniquesuffix_scan_dev[i]]) for i in range(n_runs)])
uniquesuffix_scan_test_std_string = np.std([np.max([item[0] for item in uniquesuffix_scan_test[i]]) for i in range(n_runs)])
train_std = [uniquesuffix_scan_train_std, uniquesuffix_scan_train_std_string]
dev_std = [uniquesuffix_scan_dev_std, uniquesuffix_scan_dev_std_string]
test_std = [uniquesuffix_scan_test_std, uniquesuffix_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[uniquesuffix_scan_train_ave, uniquesuffix_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[uniquesuffix_scan_dev_ave, uniquesuffix_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[uniquesuffix_scan_test_ave, uniquesuffix_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy', 'string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "unique suffix"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
simplesplit1_scan_train_ave = np.mean([np.max([item[1] for item in simplesplit1_scan_train[i]]) for i in range(n_runs)])
simplesplit1_scan_dev_ave = np.mean([np.max([item[1] for item in simplesplit1_scan_dev[i]]) for i in range(n_runs)])
simplesplit1_scan_test_ave = np.mean([np.max([item[1] for item in simplesplit1_scan_test[i]]) for i in range(n_runs)])
simplesplit1_scan_train_ave_string = np.mean([np.max([item[0] for item in simplesplit1_scan_train[i]]) for i in range(n_runs)])
simplesplit1_scan_dev_ave_string = np.mean([np.max([item[0] for item in simplesplit1_scan_dev[i]]) for i in range(n_runs)])
simplesplit1_scan_test_ave_string = np.mean([np.max([item[0] for item in simplesplit1_scan_test[i]]) for i in range(n_runs)])

# %%
simplesplit1_scan_train_std = np.std([np.max([item[1] for item in simplesplit1_scan_train[i]]) for i in range(n_runs)])
simplesplit1_scan_dev_std = np.std([np.max([item[1] for item in simplesplit1_scan_dev[i]]) for i in range(n_runs)])
simplesplit1_scan_test_std = np.std([np.max([item[1] for item in simplesplit1_scan_test[i]]) for i in range(n_runs)])
simplesplit1_scan_train_std_string = np.std([np.max([item[0] for item in simplesplit1_scan_train[i]]) for i in range(n_runs)])
simplesplit1_scan_dev_std_string = np.std([np.max([item[0] for item in simplesplit1_scan_dev[i]]) for i in range(n_runs)])
simplesplit1_scan_test_std_string = np.std([np.max([item[0] for item in simplesplit1_scan_test[i]]) for i in range(n_runs)])
train_std = [simplesplit1_scan_train_std, simplesplit1_scan_train_std_string]
dev_std = [simplesplit1_scan_dev_std, simplesplit1_scan_dev_std_string]
test_std = [simplesplit1_scan_test_std, simplesplit1_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[simplesplit1_scan_train_ave, simplesplit1_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[simplesplit1_scan_dev_ave, simplesplit1_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[simplesplit1_scan_test_ave, simplesplit1_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy', 'string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "simple split 1"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
verbarg_scan_train_ave = np.mean([np.max([item[1] for item in verbarg_scan_train[i]]) for i in range(n_runs)])
verbarg_scan_dev_ave = np.mean([np.max([item[1] for item in verbarg_scan_dev[i]]) for i in range(n_runs)])
verbarg_scan_test_ave = np.mean([np.max([item[1] for item in verbarg_scan_test[i]]) for i in range(n_runs)])
verbarg_scan_train_ave_string = np.mean([np.max([item[0] for item in verbarg_scan_train[i]]) for i in range(n_runs)])
verbarg_scan_dev_ave_string = np.mean([np.max([item[0] for item in verbarg_scan_dev[i]]) for i in range(n_runs)])
verbarg_scan_test_ave_string = np.mean([np.max([item[0] for item in verbarg_scan_test[i]]) for i in range(n_runs)])

# %%
verbarg_scan_train_std = np.std([np.max([item[1] for item in verbarg_scan_train[i]]) for i in range(n_runs)])
verbarg_scan_dev_std = np.std([np.max([item[1] for item in verbarg_scan_dev[i]]) for i in range(n_runs)])
verbarg_scan_test_std = np.std([np.max([item[1] for item in verbarg_scan_test[i]]) for i in range(n_runs)])
verbarg_scan_train_std_string = np.std([np.max([item[0] for item in verbarg_scan_train[i]]) for i in range(n_runs)])
verbarg_scan_dev_std_string = np.std([np.max([item[0] for item in verbarg_scan_dev[i]]) for i in range(n_runs)])
verbarg_scan_test_std_string = np.std([np.max([item[0] for item in verbarg_scan_test[i]]) for i in range(n_runs)])
train_std = [verbarg_scan_train_std, verbarg_scan_train_std_string]
dev_std = [verbarg_scan_dev_std, verbarg_scan_dev_std_string]
test_std = [verbarg_scan_test_std, verbarg_scan_test_std_string]

# %%
c = np.array([0, 1])
w = 0.3

plt.bar(c-w,[verbarg_scan_train_ave, verbarg_scan_train_ave_string],yerr=train_std,width=w)
plt.bar(c,[verbarg_scan_dev_ave, verbarg_scan_dev_ave_string],yerr=dev_std,width=w)
plt.bar(c+w,[verbarg_scan_test_ave, verbarg_scan_test_ave_string],yerr=test_std,width=w)
plt.xticks(c,['token based accuracy', 'string based accuracy'])
plt.ylabel('Accuracy')
plt.title('Performance "argument based"')
plt.legend(['train','dev','test'],loc=[0.82,0.5])
plt.show()

# %%
plt.rcParams["figure.figsize"] = (13,3)

# %%
xticks = ["simple", "jump", "turn left removed", "turn x", "churn y"]
c = np.array([0, 1, 2, 3, 4])
w = 0.3

plt.bar(c-w,[simple_scan_train_ave, addjump_scan_train_ave, addleft_removedleft_scan_train_ave, addx_scan_train_ave, churny_scan_train_ave], 
yerr = [simple_scan_train_std, addjump_scan_train_std, addleft_removedleft_scan_train_std, addx_scan_train_std, churny_scan_train_std],width=w)
plt.bar(c,[simple_scan_dev_ave, addjump_scan_dev_ave, addleft_removedleft_scan_dev_ave, addx_scan_dev_ave, churny_scan_dev_ave],
yerr = [simple_scan_dev_std, addjump_scan_dev_std, addleft_removedleft_scan_dev_std, addx_scan_dev_std, churny_scan_dev_std],width=w)
plt.bar(c+w,[simple_scan_test_ave, addjump_scan_test_ave, addleft_removedleft_scan_test_ave, addx_scan_test_ave, churny_scan_test_ave],
yerr = [simple_scan_test_std, addjump_scan_test_std, addleft_removedleft_scan_test_std, addx_scan_test_std, churny_scan_test_std], width=w)
plt.xticks(c,xticks)
plt.ylabel('Accuracy')
plt.title('Token based performance on reproductions from Athmer & Paperno (2021)')
plt.legend(['train', 'dev', 'test'],loc=[0.95,0.8])
plt.show()

# %%
xticks = ["simple", "jump", "turn left removed", "turn x", "churn y"]
c = np.array([0, 1, 2, 3, 4])
w = 0.3

plt.bar(c-w,[simple_scan_train_ave_string, addjump_scan_train_ave_string, addleft_removedleft_scan_train_ave_string, addx_scan_train_ave_string, churny_scan_train_ave_string], 
yerr = [simple_scan_train_std_string, addjump_scan_train_std_string, addleft_removedleft_scan_train_std_string, addx_scan_train_std_string, churny_scan_train_std_string],width=w)
plt.bar(c,[simple_scan_dev_ave_string, addjump_scan_dev_ave_string, addleft_removedleft_scan_dev_ave_string, addx_scan_dev_ave_string, churny_scan_dev_ave_string],
yerr = [simple_scan_dev_std_string, addjump_scan_dev_std_string, addleft_removedleft_scan_dev_std_string, addx_scan_dev_std_string, churny_scan_dev_std_string],width=w)
plt.bar(c+w,[simple_scan_test_ave_string, addjump_scan_test_ave_string, addleft_removedleft_scan_test_ave_string, addx_scan_test_ave_string, churny_scan_test_ave_string],
yerr = [simple_scan_test_std_string, addjump_scan_test_std_string, addleft_removedleft_scan_test_std_string, addx_scan_test_std_string, churny_scan_test_std_string], width=w)
plt.xticks(c,xticks)
plt.ylabel('Accuracy')
plt.title('String based performance on reproductions from Athmer & Paperno (2021)')
plt.legend(['train', 'dev', 'test'],loc=[0.95,0.8])
plt.show()

# %%
xticks = ["simple", "simple split 1", "jump", "split 1", "split 2", "-o", "unique suffix", "argument based"]
c = np.array([0, 1, 2, 3, 4, 5, 6, 7])
w = 0.3

plt.bar(c-w,[simple_scan_train_ave, simplesplit1_scan_train_ave, addjump_scan_train_ave, split1_scan_train_ave, split2_scan_train_ave, jumpo_scan_train_ave, uniquesuffix_scan_train_ave, verbarg_scan_train_ave], 
yerr = [simple_scan_train_std, simplesplit1_scan_train_std, addjump_scan_train_std, split1_scan_train_std, split2_scan_train_std, jumpo_scan_train_std, uniquesuffix_scan_train_std, verbarg_scan_train_std], width=w)
plt.bar(c,[simple_scan_dev_ave, simplesplit1_scan_dev_ave, addjump_scan_dev_ave, split1_scan_dev_ave, split2_scan_dev_ave, jumpo_scan_dev_ave, uniquesuffix_scan_dev_ave, verbarg_scan_dev_ave],
yerr = [simple_scan_dev_std, simplesplit1_scan_dev_std, addjump_scan_dev_std, split1_scan_dev_std, split2_scan_dev_std, jumpo_scan_dev_std, uniquesuffix_scan_dev_std, verbarg_scan_dev_std],width=w)
plt.bar(c+w,[simple_scan_test_ave, simplesplit1_scan_test_ave, addjump_scan_test_ave, split1_scan_test_ave, split2_scan_test_ave, jumpo_scan_test_ave, uniquesuffix_scan_test_ave, verbarg_scan_test_ave],
yerr = [simple_scan_test_std, simplesplit1_scan_test_std, addjump_scan_test_std, split1_scan_test_std, split2_scan_test_std, jumpo_scan_test_std, uniquesuffix_scan_test_std, verbarg_scan_test_std], width=w)
plt.xticks(c, xticks)
plt.ylabel('Accuracy')
plt.title('Token based performances of all new splits compared to simple and jump split')
plt.legend(['train', 'dev', 'test'],loc=[0.95,0.8])
plt.show()

# %%
xticks = ["simple", "simple split 1", "jump", "split 1", "split 2", "-o", "unique suffix", "argument based"]
c = np.array([0, 1, 2, 3, 4, 5, 6, 7])
w = 0.3

plt.bar(c-w,[simple_scan_train_ave_string, simplesplit1_scan_train_ave_string, addjump_scan_train_ave_string, split1_scan_train_ave_string, split2_scan_train_ave_string, jumpo_scan_train_ave_string, uniquesuffix_scan_train_ave_string, verbarg_scan_train_ave_string], 
yerr = [simple_scan_train_std_string, simplesplit1_scan_train_std_string, addjump_scan_train_std_string, split1_scan_train_std_string, split2_scan_train_std_string, jumpo_scan_train_std_string, uniquesuffix_scan_train_std_string, verbarg_scan_train_std_string], width=w)
plt.bar(c,[simple_scan_dev_ave_string, simplesplit1_scan_dev_ave_string, addjump_scan_dev_ave_string, split1_scan_dev_ave_string, split2_scan_dev_ave_string, jumpo_scan_dev_ave_string, uniquesuffix_scan_dev_ave_string, verbarg_scan_dev_ave_string],
yerr = [simple_scan_dev_std_string, simplesplit1_scan_dev_std_string, addjump_scan_dev_std_string, split1_scan_dev_std_string, split2_scan_dev_std_string, jumpo_scan_dev_std_string, uniquesuffix_scan_dev_std_string, verbarg_scan_dev_std_string],width=w)
plt.bar(c+w,[simple_scan_test_ave_string, simplesplit1_scan_test_ave_string, addjump_scan_test_ave_string, split1_scan_test_ave_string, split2_scan_test_ave_string, jumpo_scan_test_ave_string, uniquesuffix_scan_test_ave_string, verbarg_scan_test_ave_string],
yerr = [simple_scan_test_std_string, simplesplit1_scan_test_std_string, addjump_scan_test_std_string, split1_scan_test_std_string, split2_scan_test_std_string, jumpo_scan_test_std_string, uniquesuffix_scan_test_std_string, verbarg_scan_test_std_string], width=w)
plt.xticks(c, xticks)
plt.ylabel('Accuracy')
plt.title('String based performances of all new splits compared to simple and jump split')
plt.legend(['train', 'dev', 'test'],loc=[0.95,0.8])
plt.show()

# %%
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %% [markdown]
# ## Significance testing

# %%
simple_test_accs = [np.max([item[1] for item in simple_scan_test[i]]) for i in range(n_runs)]
jump_test_accs = [np.max([item[1] for item in addjump_scan_test[i]]) for i in range(n_runs)]
turnleftremoved_test_accs = [np.max([item[1] for item in addleft_removedleft_scan_test[i]]) for i in range(n_runs)]
turnx_test_accs = [np.max([item[1] for item in addx_scan_test[i]]) for i in range(n_runs)]
churny_test_accs = [np.max([item[1] for item in churny_scan_test[i]]) for i in range(n_runs)]
split1_test_accs = [np.max([item[1] for item in split1_scan_test[i]]) for i in range(n_runs)]
split2_test_accs = [np.max([item[1] for item in split2_scan_test[i]]) for i in range(n_runs)]
jumpo_test_accs = [np.max([item[1] for item in jumpo_scan_test[i]]) for i in range(n_runs)]
uniquesuffix_test_accs = [np.max([item[1] for item in uniquesuffix_scan_test[i]]) for i in range(n_runs)]
verbarg_test_accs = [np.max([item[1] for item in verbarg_scan_test[i]]) for i in range(n_runs)]
simplesplit1_test_accs = [np.max([item[1] for item in simplesplit1_scan_test[i]]) for i in range(n_runs)]

# %%
simple_test_accs_string = [np.max([item[0] for item in simple_scan_test[i]]) for i in range(n_runs)]
jump_test_accs_string = [np.max([item[0] for item in addjump_scan_test[i]]) for i in range(n_runs)]
turnleftremoved_test_accs_string = [np.max([item[0] for item in addleft_removedleft_scan_test[i]]) for i in range(n_runs)]
turnx_test_accs_string = [np.max([item[0] for item in addx_scan_test[i]]) for i in range(n_runs)]
churny_test_accs_string = [np.max([item[0] for item in churny_scan_test[i]]) for i in range(n_runs)]
split1_test_accs_string = [np.max([item[0] for item in split1_scan_test[i]]) for i in range(n_runs)]
split2_test_accs_string = [np.max([item[0] for item in split2_scan_test[i]]) for i in range(n_runs)]
jumpo_test_accs_string = [np.max([item[0] for item in jumpo_scan_test[i]]) for i in range(n_runs)]
uniquesuffix_test_accs_string = [np.max([item[0] for item in uniquesuffix_scan_test[i]]) for i in range(n_runs)]
verbarg_test_accs_string = [np.max([item[1] for item in verbarg_scan_test[i]]) for i in range(n_runs)]
simplesplit1_test_accs_string = [np.max([item[0] for item in simplesplit1_scan_test[i]]) for i in range(n_runs)]

# %%
from scipy.stats import wilcoxon

simple_simplesplit1 = wilcoxon(simple_test_accs, simplesplit1_test_accs)
simple_jump = wilcoxon(simple_test_accs, jump_test_accs)
simple_turnleftremoved = wilcoxon(simple_test_accs, turnleftremoved_test_accs)
simple_turnx = wilcoxon(simple_test_accs, turnx_test_accs)
simple_churny = wilcoxon(simple_test_accs, churny_test_accs)
jump_turnleftremoved = wilcoxon(jump_test_accs, turnleftremoved_test_accs)
turnleftremoved_turnx = wilcoxon(turnleftremoved_test_accs, turnx_test_accs)
turnleftremoved_churny = wilcoxon(turnleftremoved_test_accs, churny_test_accs)
jump_turnx = wilcoxon(jump_test_accs, turnx_test_accs)
jump_churny = wilcoxon(jump_test_accs, churny_test_accs)
turnx_churny = wilcoxon(turnx_test_accs, churny_test_accs)
jump_split1 = wilcoxon(jump_test_accs, split1_test_accs)
jump_split2 = wilcoxon(jump_test_accs, split2_test_accs)
jump_jumpo = wilcoxon(jump_test_accs, jumpo_test_accs)
jump_uniquesuffix = wilcoxon(jump_test_accs, uniquesuffix_test_accs)
jump_argument = wilcoxon(jump_test_accs, verbarg_test_accs)
split1_split2 = wilcoxon(split1_test_accs, split2_test_accs)
simple_jump = wilcoxon(simple_test_accs, jump_test_accs)
split1_jumpo = wilcoxon(split1_test_accs, jumpo_test_accs)
split2_jumpo = wilcoxon(split2_test_accs, jumpo_test_accs)
uniquesuffix_jumpo = wilcoxon(uniquesuffix_test_accs, jumpo_test_accs)
verbarg_jumpo = wilcoxon(verbarg_test_accs, jumpo_test_accs)
split1_verbarg = wilcoxon(split1_test_accs, verbarg_test_accs)
split2_verbarg = wilcoxon(split2_test_accs, verbarg_test_accs)
uniquesuffix_verbarg = wilcoxon(uniquesuffix_test_accs, verbarg_test_accs)
uniquesuffix_split1 = wilcoxon(uniquesuffix_test_accs, split1_test_accs)
uniquesuffix_split2 = wilcoxon(uniquesuffix_test_accs, split2_test_accs)

# %%
simple_simplesplit1_string = wilcoxon(simple_test_accs_string, simplesplit1_test_accs_string)
simple_jump_string = wilcoxon(simple_test_accs_string, jump_test_accs_string)
simple_turnleftremoved_string = wilcoxon(simple_test_accs_string, turnleftremoved_test_accs_string)
simple_turnx_string = wilcoxon(simple_test_accs_string, turnx_test_accs_string)
simple_churny_string = wilcoxon(simple_test_accs_string, churny_test_accs_string)
jump_turnleftremoved_string = wilcoxon(jump_test_accs_string, turnleftremoved_test_accs_string)
turnleftremoved_turnx_string = wilcoxon(turnleftremoved_test_accs_string, turnx_test_accs_string)
turnleftremoved_churny_string = wilcoxon(turnleftremoved_test_accs_string, churny_test_accs_string)
jump_turnx_string = wilcoxon(jump_test_accs_string, turnx_test_accs_string)
jump_churny_string = wilcoxon(jump_test_accs_string, churny_test_accs_string)
turnx_churny_string = wilcoxon(turnx_test_accs_string, churny_test_accs_string)
jump_split1_string = wilcoxon(jump_test_accs_string, split1_test_accs_string)
jump_split2_string = wilcoxon(jump_test_accs_string, split2_test_accs_string)
jump_jumpo_string = wilcoxon(jump_test_accs_string, jumpo_test_accs_string)
jump_uniquesuffix_string = wilcoxon(jump_test_accs_string, uniquesuffix_test_accs_string)
jump_argument_string = wilcoxon(jump_test_accs_string, verbarg_test_accs_string)
split1_split2_string = wilcoxon(split1_test_accs_string, split2_test_accs_string)
simple_jump_string = wilcoxon(simple_test_accs_string, jump_test_accs_string)
split1_jumpo_string = wilcoxon(split1_test_accs_string, jumpo_test_accs_string)
split2_jumpo_string = wilcoxon(split2_test_accs_string, jumpo_test_accs_string)
uniquesuffix_jumpo_string = wilcoxon(uniquesuffix_test_accs_string, jumpo_test_accs_string)
verbarg_jumpo_string = wilcoxon(verbarg_test_accs_string, jumpo_test_accs_string)
split1_verbarg_string = wilcoxon(split1_test_accs_string, verbarg_test_accs_string)
split2_verbarg_string = wilcoxon(split2_test_accs_string, verbarg_test_accs_string)
uniquesuffix_verbarg_string = wilcoxon(uniquesuffix_test_accs_string, verbarg_test_accs_string)
uniquesuffix_split1_string = wilcoxon(uniquesuffix_test_accs_string, split1_test_accs_string)
uniquesuffix_split2_string = wilcoxon(uniquesuffix_test_accs_string, split2_test_accs_string)
# Out:
# /home/lois/.local/lib/python3.8/site-packages/scipy/stats/morestats.py:3141: UserWarning: Exact p-value calculation does not work if there are ties. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /home/lois/.local/lib/python3.8/site-packages/scipy/stats/morestats.py:3155: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %% [markdown]
# ### token based significance testing

# %%
print("Difference simple and simple split 1: ", simple_simplesplit1) 
print("Difference simple and turn left removed: ", simple_turnleftremoved) 
print("Difference simple and turn x: ", simple_turnx)
print("Difference simple and churn y: ", simple_churny)
print("Difference jump and turn left removed: ", jump_turnleftremoved) 
print("Difference jump and turn x: ", jump_turnx) 
print("Difference jump and churn y: ", jump_churny) 
print("Difference turn x and churn y: ", turnx_churny) 
print("Difference turn left removed and turn x: ", turnleftremoved_turnx)
print("Difference turn left removed and churn y: ", turnleftremoved_churny) 
print("Difference simple and jump: ", simple_jump) 
print("Difference jump and split 1: ", jump_split1)
print("Difference jump and split 2: ", jump_split2) 
print("Difference jump and -o: ", jump_jumpo)
print("Difference jump and unique suffix: ", jump_uniquesuffix)
print("Difference jump and argument based: ", jump_argument)
print("Difference split 1 and split 2: ", split1_split2)
print("Difference split 1 and -o: ", split1_jumpo)
print("Difference split 2 and -o: ", split2_jumpo)
print("Difference unique suffix and -o: ", uniquesuffix_jumpo)
print("Difference argument based and -o: ", verbarg_jumpo)
print("Difference split 1 and argument based: ", split1_verbarg)
print("Difference split 2 and argument based: ", split2_verbarg)
print("Difference unique suffix and argument based: ", uniquesuffix_verbarg)
print("Difference unique suffix and split 1: ", uniquesuffix_split1)
print("Difference unique suffix and split 2: ", uniquesuffix_split2)
# Out:
# Difference simple and simple split 1:  WilcoxonResult(statistic=21.0, pvalue=0.556640625)
# Difference simple and turn left removed:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference simple and turn x:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference simple and churn y:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference jump and turn left removed:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference jump and turn x:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference jump and churn y:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference turn x and churn y:  WilcoxonResult(statistic=25.0, pvalue=0.845703125)
# Difference turn left removed and turn x:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference turn left removed and churn y:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference simple and jump:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# ...

# %% [markdown]
# ### string based significance testing

# %%
print("Difference simple and simple split 1: ", simple_simplesplit1_string) 
print("Difference simple and turn left removed: ", simple_turnleftremoved_string) 
print("Difference simple and turn x: ", simple_turnx_string)
print("Difference simple and churn y: ", simple_churny_string)
print("Difference jump and turn left removed: ", jump_turnleftremoved_string) 
print("Difference jump and turn x: ", jump_turnx_string) 
print("Difference jump and churn y: ", jump_churny_string) 
print("Difference turn x and churn y: ", turnx_churny_string) 
print("Difference turn left removed and turn x: ", turnleftremoved_turnx_string)
print("Difference turn left removed and churn y: ", turnleftremoved_churny_string) 
print("Difference simple and jump: ", simple_jump_string) 
print("Difference jump and split 1: ", jump_split1_string)
print("Difference jump and split 2: ", jump_split2_string) 
print("Difference jump and -o: ", jump_jumpo_string)
print("Difference jump and unique suffix: ", jump_uniquesuffix_string)
print("Difference jump and argument based: ", jump_argument_string)
print("Difference split 1 and split 2: ", split1_split2_string)
print("Difference split 1 and -o: ", split1_jumpo_string)
print("Difference split 2 and -o: ", split2_jumpo_string)
print("Difference unique suffix and -o: ", uniquesuffix_jumpo_string)
print("Difference argument based and -o: ", verbarg_jumpo_string)
print("Difference split 1 and argument based: ", split1_verbarg_string)
print("Difference split 2 and argument based: ", split2_verbarg_string)
print("Difference unique suffix and argument based: ", uniquesuffix_verbarg_string)
print("Difference unique suffix and split 1: ", uniquesuffix_split1_string)
print("Difference unique suffix and split 2: ", uniquesuffix_split2_string)
# Out:
# Difference simple and simple split 1:  WilcoxonResult(statistic=16.0, pvalue=0.275390625)
# Difference simple and turn left removed:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference simple and turn x:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference simple and churn y:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference jump and turn left removed:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference jump and turn x:  WilcoxonResult(statistic=9.0, pvalue=0.064453125)
# Difference jump and churn y:  WilcoxonResult(statistic=6.0, pvalue=0.02734375)
# Difference turn x and churn y:  WilcoxonResult(statistic=11.0, pvalue=0.17269378073166064)
# Difference turn left removed and turn x:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference turn left removed and churn y:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# Difference simple and jump:  WilcoxonResult(statistic=0.0, pvalue=0.001953125)
# ...
